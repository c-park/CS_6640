% %% [markdown]
% ###

% %%
format compact

% %%
im_rgb = imread('im2.jpg');
im = rgb2gray(im_rgb);
figure(1);imshow(im); title('Original - gray');
figure(2);imshow(im_rgb); title('Original');

% %%
T = CS6640_FFT_texture(im);
[cidx,ctrs] = kmeans(T,9);
% Out:
% ...
% > In kmeans/loopBody (line 466)
%   In internal.stats.parallel.smartForReduce (line 136)
%   In kmeans (line 335)

% %%
combo(mat2gray(im),(reshape(cidx==1,480,640)));title('K=1');
combo(mat2gray(im),(reshape(cidx==2,480,640)));title('K=2');
combo(mat2gray(im),(reshape(cidx==3,480,640)));title('K=3');
combo(mat2gray(im),(reshape(cidx==4,480,640)));title('K=4');
combo(mat2gray(im),(reshape(cidx==5,480,640)));title('K=5');
combo(mat2gray(im),(reshape(cidx==6,480,640)));title('K=6');
combo(mat2gray(im),(reshape(cidx==7,480,640)));title('K=7');
combo(mat2gray(im),(reshape(cidx==8,480,640)));title('K=8');
combo(mat2gray(im),(reshape(cidx==9,480,640)));title('K=9');
%combo(mat2gray(im),(reshape(cidx==1,480,640)));title('K=1');
%combo(mat2gray(im),(reshape(cidx==1,480,640)));title('K=1');
